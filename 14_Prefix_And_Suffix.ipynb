# %%
import pandas as pd

# %%
df=pd.read_csv('data/cars.csv')
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# ## ADD PREFIX

# %%
df.add_prefix('_items')
# Out:
#                      _itemsCar  _itemsMPG  _itemsCylinders  \
# 0    Chevrolet Chevelle Malibu       18.0              8.0
# 1            Buick Skylark 320       15.0              8.0
# 2           Plymouth Satellite       18.0              8.0
# 3                AMC Rebel SST       16.0              8.0
# 4                  Ford Torino       17.0              8.0
# ..                         ...        ...              ...
# 401            Ford Mustang GL       27.0              4.0
# 402          Volkswagen Pickup       44.0              4.0
# 403              Dodge Rampage       32.0              4.0
# 404                Ford Ranger       28.0              4.0
# 405                 Chevy S-10       31.0              4.0
#
#      _itemsDisplacement  _itemsHorsepower  _itemsWeight  _itemsAcceleration  \
# 0                 307.0             130.0          3504                12.0
# 1                 350.0             165.0          3693                11.5
# ...

# %%
df['Car'].add_prefix('Car')
# Out:
# Car0      Chevrolet Chevelle Malibu
# Car1              Buick Skylark 320
# Car2             Plymouth Satellite
# Car3                  AMC Rebel SST
# Car4                    Ford Torino
#                     ...
# Car401              Ford Mustang GL
# Car402            Volkswagen Pickup
# Car403                Dodge Rampage
# Car404                  Ford Ranger
# Car405                   Chevy S-10
# Name: Car, Length: 406, dtype: object

# %% [markdown]
# ## Add Suffix

# %%
df.add_suffix('_item')
# Out:
#                       Car_item  MPG_item  Cylinders_item  Displacement_item  \
# 0    Chevrolet Chevelle Malibu      18.0             8.0              307.0
# 1            Buick Skylark 320      15.0             8.0              350.0
# 2           Plymouth Satellite      18.0             8.0              318.0
# 3                AMC Rebel SST      16.0             8.0              304.0
# 4                  Ford Torino      17.0             8.0              302.0
# ..                         ...       ...             ...                ...
# 401            Ford Mustang GL      27.0             4.0              140.0
# 402          Volkswagen Pickup      44.0             4.0               97.0
# 403              Dodge Rampage      32.0             4.0              135.0
# 404                Ford Ranger      28.0             4.0              120.0
# 405                 Chevy S-10      31.0             4.0              119.0
#
# ...

# %%
df['Car'].add_suffix('_Car')
# Out:
# 0_Car      Chevrolet Chevelle Malibu
# 1_Car              Buick Skylark 320
# 2_Car             Plymouth Satellite
# 3_Car                  AMC Rebel SST
# 4_Car                    Ford Torino
#                      ...
# 401_Car              Ford Mustang GL
# 402_Car            Volkswagen Pickup
# 403_Car                Dodge Rampage
# 404_Car                  Ford Ranger
# 405_Car                   Chevy S-10
# Name: Car, Length: 406, dtype: object
