# %%
import pandas as pd

# %%
df=pd.read_csv('data/cars.csv')
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
df=df.truncate(10,18)
df
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 10              Citroen DS-21 Pallas   0.0        4.0         133.0
# 11  Chevrolet Chevelle Concours (sw)   0.0        8.0         350.0
# 12                  Ford Torino (sw)   0.0        8.0         351.0
# 13           Plymouth Satellite (sw)   0.0        8.0         383.0
# 14                AMC Rebel SST (sw)   0.0        8.0         360.0
# 15               Dodge Challenger SE  15.0        8.0         383.0
# 16                Plymouth 'Cuda 340  14.0        8.0         340.0
# 17             Ford Mustang Boss 302   0.0        8.0         302.0
# 18             Chevrolet Monte Carlo  15.0        8.0         400.0
#
#     Horsepower  Weight  Acceleration  Model  Origin
# 10       115.0    3090          17.5     70  Europe
# 11         NaN    4142          11.5     70      US
# 12       153.0    4034          11.0     70      US
# 13       175.0    4166          10.5     70      US
# ...
