# %% [markdown]
# ## Read csv file

# %%
# !pip install  openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('data/cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %% [markdown]
# ## Read csv File-colen seprated value

# %%
df= pd.read_csv('data/cars.csv',delimiter=';')
df
# Out:
#     Car,MPG,Cylinders,Displacement,Horsepower,Weight,Acceleration,Model,Origin
# 0    Chevrolet Chevelle Malibu,18,8,307,130,3504,12...
# 1       Buick Skylark 320,15,8,350,165,3693,11.5,70,US
# 2          Plymouth Satellite,18,8,318,150,3436,,70,US
# 3             AMC Rebel SST,16,8,304,150,3433,12,70,US
# 4             Ford Torino,17,8,302,140,3449,10.5,70,US
# ..                                                 ...
# 401        Ford Mustang GL,27,4,140,86,2790,15.6,82,US
# 402   Volkswagen Pickup,44,4,97,52,2130,24.6,82,Europe
# 403          Dodge Rampage,32,4,135,84,2295,11.6,82,US
# 404            Ford Ranger,28,4,120,79,2625,18.6,82,US
# 405             Chevy S-10,31,4,119,82,2720,19.4,82,US
#
# [406 rows x 1 columns]

# %% [markdown]
# ## Read Excel File

# %%
df=pd.read_excel('data/cars.xlsx')
df.head()
# Out:
#                         cars Unnamed: 1 Unnamed: 2    Unnamed: 3  Unnamed: 4  \
# 0                        Car        MPG  Cylinders  Displacement  Horsepower
# 1                     STRING     DOUBLE        INT        DOUBLE      DOUBLE
# 2  Chevrolet Chevelle Malibu         18          8           307         130
# 3          Buick Skylark 320         15          8           350         165
# 4         Plymouth Satellite         18          8           318         150
#
#   Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0     Weight  Acceleration      Model     Origin
# 1     DOUBLE        DOUBLE        INT        CAT
# 2       3504            12         70         US
# 3       3693          11.5         70         US
# 4       3436           NaN         70         US

# %%
df=pd.read_excel('data/cars.xlsx',header=1)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu      18         8          307        130
# 2          Buick Skylark 320      15         8          350        165
# 3         Plymouth Satellite      18         8          318        150
# 4              AMC Rebel SST      16         8          304        150
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1    3504           12    70     US
# 2    3693         11.5    70     US
# 3    3436          NaN    70     US
# 4    3433           12    70     US

# %%
df=pd.read_excel('data/cars.xlsx',sheet_name='Summary')
df
# Out:
#              Table 1 Unnamed: 1 Unnamed: 2    Unnamed: 3  Unnamed: 4  \
# 0                Car        MPG  Cylinders  Displacement  Horsepower
# 1         Ford Pinto         18          6           171          97
# 2  Volkswagen Rabbit         29          4            90          70
# 3          AMC Pacer         19          6           232          90
# 4         Audi 100LS         23          4           115          95
# 5        Peugeot 504         23          4           120          88
# 6        Volvo 244DL         22          4           121          98
# 7          Saab 99LE         25          4           121         115
# 8   Honda Civic CVCC         33          4            91          53
# 9           Fiat 131         28          4           107          86
#
#   Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0     Weight  Acceleration      Model     Origin
# 1       2984          14.5         75         US
# 2       1937            14         75     Europe
# ...

# %%
df=pd.read_pickle('data/cars.pk')
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      18         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %% [markdown]
# ## Writing data

# %%
import pandas as pd

# %%
parthi=[200567,'parthiban','kannan',35,86.0]
aravindh=[200568,'aravindh','raja',35,86.0]
kishore=[200569,'kishore','dharaniraj',24,64.0]
df.colums=['ID','First name','Last name','Age','Weight']
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      18         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.columns=['ID','FirstName','LastName','Age','Weight']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.columns=['ID','FirstName','LastName','Age','Weight']
#       2 df
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# ...
