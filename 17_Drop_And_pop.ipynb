# %%
import pandas as pd

# %%
df=pd.read_csv('data/cars.csv')
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# ## Drop Column

# %%
df=df.drop(['Displacement','Origin'],axis=1)
df.head()
# Out:
#                          Car   MPG  Cylinders  Horsepower  Weight  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0       130.0    3504
# 1          Buick Skylark 320  15.0        8.0       165.0    3693
# 2         Plymouth Satellite  18.0        8.0       150.0    3436
# 3              AMC Rebel SST  16.0        8.0       150.0    3433
# 4                Ford Torino  17.0        8.0       140.0    3449
#
#    Acceleration  Model
# 0          12.0     70
# 1          11.5     70
# 2           NaN     70
# 3          12.0     70
# 4          10.5     70

# %% [markdown]
# ## POP Column

# %%
car=df.pop('Car')
df.head()
# Out:
#     MPG  Cylinders  Horsepower  Weight  Acceleration  Model
# 0  18.0        8.0       130.0    3504          12.0     70
# 1  15.0        8.0       165.0    3693          11.5     70
# 2  18.0        8.0       150.0    3436           NaN     70
# 3  16.0        8.0       150.0    3433          12.0     70
# 4  17.0        8.0       140.0    3449          10.5     70

# %% [markdown]
# ## Drop Duplicate

# %%
df=pd.DataFrame([
    ['Benz',18.0],
    ['Audi',16.0],
    ['Benz',17.0],
    ['Benz',18.0],
    ['Suzuki',19.0]
])
df.columns=['Car','MPG']
df
# Out:
#       Car   MPG
# 0    Benz  18.0
# 1    Audi  16.0
# 2    Benz  17.0
# 3    Benz  18.0
# 4  Suzuki  19.0

# %%
df.drop_duplicates()
# Out:
#       Car   MPG
# 0    Benz  18.0
# 1    Audi  16.0
# 2    Benz  17.0
# 4  Suzuki  19.0
