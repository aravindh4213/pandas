# %%
import pandas as pd

# %%
df=pd.read_csv('data/numbers.csv')
df.head()
# Out:
#    val1  val2  val3
# 0    78    33     2
# 1    59    58    83
# 2     2    38    19
# 3    33    17    45
# 4    30    67    11

# %%
df['max']=df['val1'].combine(df['val2'],max)
df.head()
# Out:
#    val1  val2  val3  max
# 0    78    33     2   78
# 1    59    58    83   59
# 2     2    38    19   38
# 3    33    17    45   33
# 4    30    67    11   67

# %% [markdown]
# combine First values if Null

# %%
dfA=pd.DataFrame([1,0,5,8,None,3,2,None,3])
dfB=pd.DataFrame([7,0,5,4,9,3,2,6,2])
dfA
# Out:
#      0
# 0  1.0
# 1  0.0
# 2  5.0
# 3  8.0
# 4  NaN
# 5  3.0
# 6  2.0
# 7  NaN
# 8  3.0

# %%
dfB
# Out:
#    0
# 0  7
# 1  0
# 2  5
# 3  4
# 4  9
# 5  3
# 6  2
# 7  6
# 8  2

# %%
dfA.combine_first(dfB)
# Out:
#      0
# 0  1.0
# 1  0.0
# 2  5.0
# 3  8.0
# 4  9.0
# 5  3.0
# 6  2.0
# 7  6.0
# 8  3.0
